# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("/home/koan/myHome/AGH/PracaInżynierska/pycharm_github/shor_mmik"))))

del os, sys

# %%
from tests.haner.gate_experiments.double_controlled_constant_modulo_adder import Experiment

# %%
constant = 11
n = 4
N = 13
experiment = Experiment(constant, N, n)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 2, 'x': 4, 'g': 3, 'flag': 1}

# %%
values = dict(ctrl=0b11, x=1, g=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.draw(output='mpl')

# %%
qc.decompose().draw(output='mpl')

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'0 001 1100 11': 1024}

# %%
constant = 0
n = 1
N = 1
experiment = Experiment(constant, N, n)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 2, 'x': 1, 'g': 1, 'flag': 1}

# %%
values = dict(ctrl=0b11, x=0, g=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl')

# %%
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import Unroller
pass_ = Unroller(['x', 'cx', 'ccx'])
pm = PassManager(pass_)
dec_qc = pm.run(qc)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 from qiskit.transpiler import PassManager
# ----> 2 from qiskit.transpiler.passes import Unroller
#       3 pass_ = Unroller(['x', 'cx', 'ccx'])
#       4 pm = PassManager(pass_)
#
# ImportError: cannot import name 'Unroller' from 'qiskit.transpiler.passes' (/home/koan/myHome/AGH/PracaInżynierska/pycharm_github/shor_mmik/venv/lib/python3.12/site-packages/qiskit/transpiler/passes/__init__.py)

# %%
dec_qc.draw(output='mpl')

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
