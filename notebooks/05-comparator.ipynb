# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("/home/koan/myHome/AGH/PracaInżynierska/pycharm_github/shor_mmik"))))

del os, sys

# %%
from tests.haner.gate_experiments.comparator import Experiment

# %%
constant = 11
n = 4
experiment = Experiment(constant, n)

# %%
experiment._qregs_spec
# Out:
# {'x': 4, 'g': 3, 'c': 1}

# %%
values = dict(x=10, g=4)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.draw(output='mpl')

# %%
qc.decompose().draw(output='mpl')

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'1 100 1010': 1024}

# %%
constant = 1
n = 1
experiment = Experiment(constant, n)

# %%
experiment._qregs_spec
# Out:
# {'x': 1, 'c': 1}

# %%
values = dict(x=1, g=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl')

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'0 1': 1024}
