# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("/home/koan/myHome/AGH/PracaInżynierska/pycharm_github/shor_mmik"))))

del os, sys

# %%
from tests.haner.gate_experiments.controlled_incrementer import Experiment

# %%
n = 5
experiment = Experiment(n)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 1, 'x': 5, 'g': 5}

# %%
values = dict(ctrl=0b1, x=10, g=7)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'00111 01011 1': 1024}

# %%
n = 2
experiment = Experiment(2)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 1, 'x': 2, 'g': 2}

# %%
values = dict(ctrl=0b0, x=1, g=2)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'10 01 0': 1024}

# %%
n = 1
experiment = Experiment(1)

# %%
values = dict(ctrl=0b0, x=1, g=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'1 1 0': 1024}
