# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("/home/koan/myHome/AGH/PracaInżynierska/pycharm_github/shor_mmik"))))

del os, sys

# %%
# from tests.haner.gate_experiments.controlled_U_gate import Experiment

# Moje zmiany

# Zmiana importu bramki do eksperymentu (prawdopodobnie była podana niewłaściwa)
from tests.haner.gate_experiments.controlled_modular_multiplication_gate import Experiment

# %%
constant = 11
n = 4
N = 13
experiment = Experiment(constant, N, n)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 1, 'x': 4, 'aux': 4, 'flag': 1}

# %%
values = dict(ctrl=0b1, x=10, y=0)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.draw(output='mpl')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'0 0000 0110 1': 1024}
