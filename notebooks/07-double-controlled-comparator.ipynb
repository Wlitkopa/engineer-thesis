# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("/home/koan/myHome/AGH/PracaInżynierska/pycharm_github/shor_mmik"))))

del os, sys

# %%
from tests.haner.gate_experiments.double_controlled_comparator import Experiment

# %%
constant = 11
n = 4
experiment = Experiment(constant, n)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 2, 'x': 4, 'g': 3, 'c': 1}

# %%
values = dict(ctrl=0b11, x=10, g=4)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.draw(output='mpl')

# %%
qc.decompose().draw(output='mpl')

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'1 100 1010 11': 1024}

# %%
constant = 1
n = 1
experiment = Experiment(constant, n)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 2, 'x': 1, 'g': 1, 'c': 1}

# %%
values = dict(ctrl=0b11, x=0, g=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl')

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'1 1 0 11': 1024}
